# %% [markdown]
# ### 0. Import Dependencies

# %%
import gymnasium as gym

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy

# %%
import torch

# %% [markdown]
# ### 1. Test Random Environment

# %%
environment_name = "LunarLander-v2"

# %%
env = gym.make(environment_name, render_mode="human")

# %%
observation, info = env.reset()
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        action = env.action_space.sample()
        observation, reward, terminated, truncated, info = env.step(action)
        score += reward

        if terminated or truncated:
            done = True
            observation, info = env.reset()

    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-321.9361291948418
# Episode:2 Score:-54.46637076577062
# Episode:3 Score:25.082779316715445
# Episode:4 Score:-123.42909330492785
# Episode:5 Score:-136.83723576124498
# Episode:6 Score:-176.84204629765202
# Episode:7 Score:-289.8219221742401
# Episode:8 Score:-162.5477972048547
# Episode:9 Score:-230.3834218475242
# Episode:10 Score:-248.65455177510654

# %% [markdown]
# ### 2. Build and Train the Model

# %%
env = gym.make(environment_name, render_mode="human")
env = Monitor(env)
env = DummyVecEnv([lambda: env])
model = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000, log_interval=4)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 41       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 364      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.4     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 43       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.3     |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 44       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 964      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.7     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 45       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.4     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 45       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 1688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.6     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 45       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 45       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 45       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 46       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 3110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 45       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 3511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 45       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 3857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 45       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 4253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 45       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 4614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 45       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 4995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 45       |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 5408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 46       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 5827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 46       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 6208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 46       |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 6538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 46       |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 6855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 46       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 7198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 46       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 7651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 46       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 8051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 46       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 8505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 46       |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 8905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 46       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 9167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.098    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 46       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 9495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.0693   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 46       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 9797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 46       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 10176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 46       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 10550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 46       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 10898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 46       |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 11272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 46       |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 11649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 46       |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 12887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 46       |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 13238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 46       |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 13580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 46       |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 13918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 46       |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 14258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 46       |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 14616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 46       |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 14987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 46       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 15396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 46       |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 15732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 46       |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 16068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 46       |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 16436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 46       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 16806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 46       |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 17143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 46       |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 17497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 46       |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 17876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 46       |
# |    time_elapsed     | 393      |
# |    total_timesteps  | 18242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 46       |
# |    time_elapsed     | 401      |
# |    total_timesteps  | 18658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 46       |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 19029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 46       |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 20374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 46       |
# |    time_elapsed     | 446      |
# |    total_timesteps  | 20764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 46       |
# |    time_elapsed     | 454      |
# |    total_timesteps  | 21140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 46       |
# |    time_elapsed     | 463      |
# |    total_timesteps  | 21539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 46       |
# |    time_elapsed     | 470      |
# |    total_timesteps  | 21903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 46       |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 22206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 46       |
# |    time_elapsed     | 485      |
# |    total_timesteps  | 22579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 46       |
# |    time_elapsed     | 493      |
# |    total_timesteps  | 22957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 46       |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 23291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 46       |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 23640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 46       |
# |    time_elapsed     | 515      |
# |    total_timesteps  | 23977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 46       |
# |    time_elapsed     | 523      |
# |    total_timesteps  | 24334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 46       |
# |    time_elapsed     | 531      |
# |    total_timesteps  | 24738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 46       |
# |    time_elapsed     | 538      |
# |    total_timesteps  | 25052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 46       |
# |    time_elapsed     | 547      |
# |    total_timesteps  | 25483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 46       |
# |    time_elapsed     | 555      |
# |    total_timesteps  | 25866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 46       |
# |    time_elapsed     | 564      |
# |    total_timesteps  | 26291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 46       |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 26641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 46       |
# |    time_elapsed     | 580      |
# |    total_timesteps  | 27029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 46       |
# |    time_elapsed     | 588      |
# |    total_timesteps  | 27370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 46       |
# |    time_elapsed     | 596      |
# |    total_timesteps  | 27749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 46       |
# |    time_elapsed     | 603      |
# |    total_timesteps  | 28100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 46       |
# |    time_elapsed     | 612      |
# |    total_timesteps  | 28516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 46       |
# |    time_elapsed     | 620      |
# |    total_timesteps  | 28908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 46       |
# |    time_elapsed     | 628      |
# |    total_timesteps  | 29272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 46       |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 29648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 46       |
# |    time_elapsed     | 644      |
# |    total_timesteps  | 30007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 46       |
# |    time_elapsed     | 653      |
# |    total_timesteps  | 30365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 46       |
# |    time_elapsed     | 660      |
# |    total_timesteps  | 30693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 46       |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 31077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 46       |
# |    time_elapsed     | 676      |
# |    total_timesteps  | 31455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 46       |
# |    time_elapsed     | 684      |
# |    total_timesteps  | 31846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 46       |
# |    time_elapsed     | 691      |
# |    total_timesteps  | 32178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 46       |
# |    time_elapsed     | 700      |
# |    total_timesteps  | 32574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 46       |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 32993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 46       |
# |    time_elapsed     | 716      |
# |    total_timesteps  | 33298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 46       |
# |    time_elapsed     | 724      |
# |    total_timesteps  | 33643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 46       |
# |    time_elapsed     | 732      |
# |    total_timesteps  | 34030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 46       |
# |    time_elapsed     | 740      |
# |    total_timesteps  | 34401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 46       |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 34760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 46       |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 35170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 46       |
# |    time_elapsed     | 765      |
# |    total_timesteps  | 35544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 46       |
# |    time_elapsed     | 774      |
# |    total_timesteps  | 35990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 46       |
# |    time_elapsed     | 782      |
# |    total_timesteps  | 36370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 46       |
# |    time_elapsed     | 790      |
# |    total_timesteps  | 36733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 46       |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 37071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 46       |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 37482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 46       |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 37908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 46       |
# |    time_elapsed     | 822      |
# |    total_timesteps  | 38203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 46       |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 38492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 46       |
# |    time_elapsed     | 836      |
# |    total_timesteps  | 38884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 46       |
# |    time_elapsed     | 844      |
# |    total_timesteps  | 39249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 46       |
# |    time_elapsed     | 851      |
# |    total_timesteps  | 39569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 46       |
# |    time_elapsed     | 859      |
# |    total_timesteps  | 39954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 46       |
# |    time_elapsed     | 867      |
# |    total_timesteps  | 40324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 46       |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 40660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 46       |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 41032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 46       |
# |    time_elapsed     | 890      |
# |    total_timesteps  | 41375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 46       |
# |    time_elapsed     | 899      |
# |    total_timesteps  | 41787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 46       |
# |    time_elapsed     | 906      |
# |    total_timesteps  | 42142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 46       |
# |    time_elapsed     | 914      |
# |    total_timesteps  | 42505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 46       |
# |    time_elapsed     | 921      |
# |    total_timesteps  | 42842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 46       |
# |    time_elapsed     | 929      |
# |    total_timesteps  | 43193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 46       |
# |    time_elapsed     | 937      |
# |    total_timesteps  | 43592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 46       |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 43999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 46       |
# |    time_elapsed     | 955      |
# |    total_timesteps  | 44399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 46       |
# |    time_elapsed     | 962      |
# |    total_timesteps  | 44758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 46       |
# |    time_elapsed     | 970      |
# |    total_timesteps  | 45111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 46       |
# |    time_elapsed     | 978      |
# |    total_timesteps  | 45472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 46       |
# |    time_elapsed     | 986      |
# |    total_timesteps  | 45861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 46       |
# |    time_elapsed     | 995      |
# |    total_timesteps  | 46287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 46       |
# |    time_elapsed     | 1004     |
# |    total_timesteps  | 46648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 46       |
# |    time_elapsed     | 1010     |
# |    total_timesteps  | 46945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 46       |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 47349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# ...
# |    time_elapsed     | 1085     |
# |    total_timesteps  | 50443    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -225     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 46       |
# |    time_elapsed     | 1093     |
# |    total_timesteps  | 50814    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 203      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -255     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 46       |
# |    time_elapsed     | 1105     |
# |    total_timesteps  | 51368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93     |
# |    n_updates        | 341      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -291     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 46       |
# |    time_elapsed     | 1119     |
# |    total_timesteps  | 52032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -303     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 46       |
# |    time_elapsed     | 1129     |
# |    total_timesteps  | 52494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 623      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -321     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 46       |
# |    time_elapsed     | 1152     |
# |    total_timesteps  | 53613    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 903      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -333     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 46       |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 54593    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.48     |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -343     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 46       |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 55368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.511    |
# |    n_updates        | 1341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -347     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 46       |
# |    time_elapsed     | 1225     |
# |    total_timesteps  | 57047    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.03     |
# |    n_updates        | 1761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -349     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 46       |
# |    time_elapsed     | 1267     |
# |    total_timesteps  | 59016    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.672    |
# |    n_updates        | 2253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -354     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 46       |
# |    time_elapsed     | 1307     |
# |    total_timesteps  | 60924    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 2730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | -350     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 46       |
# |    time_elapsed     | 1358     |
# |    total_timesteps  | 63367    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.681    |
# |    n_updates        | 3341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -354     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 46       |
# |    time_elapsed     | 1392     |
# |    total_timesteps  | 64920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38     |
# |    n_updates        | 3729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | -354     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 46       |
# |    time_elapsed     | 1445     |
# |    total_timesteps  | 67310    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 4327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | -358     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 46       |
# |    time_elapsed     | 1478     |
# |    total_timesteps  | 68853    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.49     |
# |    n_updates        | 4713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | -359     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 46       |
# |    time_elapsed     | 1522     |
# |    total_timesteps  | 70835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.3      |
# |    n_updates        | 5208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 244      |
# |    ep_rew_mean      | -362     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 46       |
# |    time_elapsed     | 1532     |
# |    total_timesteps  | 71314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 5328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | -367     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 46       |
# |    time_elapsed     | 1546     |
# |    total_timesteps  | 71955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.772    |
# |    n_updates        | 5488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 257      |
# |    ep_rew_mean      | -361     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 46       |
# |    time_elapsed     | 1576     |
# |    total_timesteps  | 73331    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 5832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | -365     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 46       |
# |    time_elapsed     | 1607     |
# |    total_timesteps  | 74724    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.4      |
# |    n_updates        | 6180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | -372     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 46       |
# |    time_elapsed     | 1641     |
# |    total_timesteps  | 76287    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91     |
# |    n_updates        | 6571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | -374     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 46       |
# |    time_elapsed     | 1675     |
# |    total_timesteps  | 77849    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 6962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -376     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 46       |
# |    time_elapsed     | 1691     |
# |    total_timesteps  | 78551    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98     |
# |    n_updates        | 7137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 306      |
# |    ep_rew_mean      | -376     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 46       |
# |    time_elapsed     | 1724     |
# |    total_timesteps  | 80062    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.45     |
# |    n_updates        | 7515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 327      |
# |    ep_rew_mean      | -371     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 46       |
# |    time_elapsed     | 1775     |
# |    total_timesteps  | 82519    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.767    |
# |    n_updates        | 8129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 345      |
# |    ep_rew_mean      | -345     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 46       |
# |    time_elapsed     | 1829     |
# |    total_timesteps  | 84965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 8741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 364      |
# |    ep_rew_mean      | -329     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 46       |
# |    time_elapsed     | 1878     |
# |    total_timesteps  | 87200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.953    |
# |    n_updates        | 9299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 381      |
# |    ep_rew_mean      | -295     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 46       |
# |    time_elapsed     | 1926     |
# |    total_timesteps  | 89425    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.377    |
# |    n_updates        | 9856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 385      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 46       |
# |    time_elapsed     | 1950     |
# |    total_timesteps  | 90484    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.872    |
# |    n_updates        | 10120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | -255     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 46       |
# |    time_elapsed     | 2037     |
# |    total_timesteps  | 94484    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.54     |
# |    n_updates        | 11120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | -233     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 46       |
# |    time_elapsed     | 2096     |
# |    total_timesteps  | 97270    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.772    |
# |    n_updates        | 11817    |
# ----------------------------------

# %% [markdown]
# ### 3. Save and Test the Model

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()

# %%
model.save("DQN_LunarLander")

# %%
del model

# %%
env = gym.make("LunarLander-v2", render_mode="human")
model = DQN.load("DQN_LunarLander", env=env)
obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 6
#       4 while True:
#       5     action, _states = model.predict(obs, deterministic=True)
# ----> 6     obs, reward, terminated, truncated, info = env.step(action)
#       7     if terminated or truncated:
#       8         obs, info = env.reset()
#
# File ~/anaconda3/envs/gym/lib/python3.11/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/envs/gym/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/anaconda3/envs/gym/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~/anaconda3/envs/gym/lib/python3.11/site-packages/gymnasium/envs/box2d/lunar_lander.py:675, in LunarLander.step(self, action)
#     672     reward = +100
#     674 if self.render_mode == "human":
# --> 675     self.render()
#     676 return np.array(state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/anaconda3/envs/gym/lib/python3.11/site-packages/gymnasium/envs/box2d/lunar_lander.py:787, in LunarLander.render(self)
#     785     self.screen.blit(self.surf, (0, 0))
#     786     pygame.event.pump()
# --> 787     self.clock.tick(self.metadata["render_fps"])
#     788     pygame.display.flip()
#     789 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
env.close()
